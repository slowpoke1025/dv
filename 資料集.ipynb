# %%
import pandas as pd

# %% [markdown]
# # Netflix Data from 2008 to 2021
#
# ### [未清理版本](https://www.kaggle.com/datasets/shivamb/netflix-shows)
# ### [已清理版本](https://www.kaggle.com/datasets/ariyoomotade/netflix-data-cleaning-analysis-and-visualization)
# ### [視覺化範例](https://public.tableau.com/app/profile/abdulrasaq.ariyo/viz/NetflixTVShowsMovies_16615029026580/NetflixDashboard)
#
# ### 欄位
# - show_id
# - type
# - title
# - director
# - country
# - date_added
# - release_year
# - rating
# - duration
# - listed_in
#
# ### 備註
# - 8790 X 10

# %%
# https://www.kaggle.com/datasets/ariyoomotade/netflix-data-cleaning-analysis-and-visualization

df = pd.read_csv("./netflix.csv")
df["listed_in"] = df["listed_in"].apply(lambda x: x.split(", "))
df.sort_values("release_year", ascending=False)
df["date_added"] = pd.to_datetime(df["date_added"])#.dt.strftime('%Y-%m-%d')
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %% [markdown]
# # IMDB Dataset 2023
#
# ### [已清理版本](https://www.kaggle.com/datasets/adriankiezun/imdb-dataset-2023)
#
# ### 欄位
# - **id**: movie's ID used by IMDB repository
# - **primaryTitle**: title in English
# - **originalTitle**: original title in native language
# - **isAdult**: parental guidance
# - **runtimeMinutes**: total runtime in minutes
# - **genres**: genres
# - **averageRating**: final rating, based on all the ratings
# - **numVotes**: total number of votes (ratings)
# - **budget**: total budget in USD
# - **gross**: total gross worldwide in USD
# - **release_date**: release date, first occurrence
# - **directors**: directors
#
# ### 備註
# - 3384 x 12

# %%
# https://www.kaggle.com/datasets/adriankiezun/imdb-dataset-2023
df = pd.read_csv("./imdb.csv")
df
# Out:
#              id                          primaryTitle  \
# 0     tt0035423                        Kate & Leopold
# 1     tt0065421                        The Aristocats
# 2     tt0065938                        Kelly's Heroes
# 3     tt0066026                               M*A*S*H
# 4     tt0066206                                Patton
# ...         ...                                   ...
# 3343  tt9770150                             Nomadland
# 3344  tt9777666                      The Tomorrow War
# 3345  tt9784798           Judas and the Black Messiah
# 3346  tt9844522  Escape Room: Tournament of Champions
# 3347  tt9893250                          I Care a Lot
#
#                              originalTitle  isAdult  runtimeMinutes  \
# 0                           Kate & Leopold        0             118
# 1                           The AristoCats        0              78
# 2                           Kelly's Heroes        0             144
# ...

# %% [markdown]
# # Anime Dataset
#
# ### [未清理版本](https://www.kaggle.com/datasets/arnavvvvv/anime-dataset?select=animes.csv)
#
# ### 欄位
# - **uid**
# - **title**
# - **synopsis**
# - **genre**
# - **aired**
# - **episodes**
# - **members**
# - **popularity**
# - **ranked**
# - **score**
# - **img_url**
# - **link**
#
# ### 備註
# - 13731 × 12
# - **每部動漫有圖片連結**

# %%
# https://www.kaggle.com/datasets/arnavvvvv/anime-dataset?select=animes.csv
df = pd.read_csv("./animes.csv")
df.shape[0], df.dropna().shape[0]
df = df.drop_duplicates().sort_values("ranked")
df.dropna()
# Out:
#          uid                                              title  \
# 3       5114                   Fullmetal Alchemist: Brotherhood
# 773     9253                                        Steins;Gate
# 772    11061                             Hunter x Hunter (2011)
# 771    32281                                     Kimi no Na wa.
# 770    38524                 Shingeki no Kyojin Season 3 Part 2
# ...      ...                                                ...
# 14328  28543  Zukkoke Sannin-gumi no Hi Asobi Boushi Daisakusen
# 14871  35099         Zukkoke Sannin-gumi no Jitensha Kyoushitsu
# 14870  35149               Zukkoke Sannin-gumi no Koutsuu Anzen
# 14869  18967          Zukkoke Sannin-gumi: Zukkoke Jikuu Bouken
# 14868  13455                                   Zumomo to Nupepe
#
#                                                 synopsis  \
# 3      "In order for something to be obtained, someth...
# 773    The self-proclaimed mad scientist Rintarou Oka...
# ...

# %% [markdown]
# # Customer Segmentation Data
#
# ### [已清理版本](https://www.kaggle.com/datasets/ravalsmit/customer-segmentation-data)
#
# ### 欄位
# - **Customer ID**
# - **Age**
# - **Gender**
# - **Marital Status**
# - **Education Level**
# - **Geographic Information**
# - **Occupation**
# - **Income Level**
# - **Behavioral Data**
# - **Purchase History**
# - **Interactions with Customer Service**
# - **Insurance Products Owned**
# - **Coverage Amount**
# - **Premium Amount**
# - **Policy Type**
# - **Customer Preferences**
# - **Preferred Communication Channel**
# - **Preferred Contact Time**
# - **Preferred Language**
# - **Segmentation Group**
#
# ### 備註
# - 53503 × 20

# %%
# https://www.kaggle.com/datasets/ravalsmit/customer-segmentation-data
df = pd.read_csv("./customer.csv")
df.dropna()
# Out:
#        Customer ID  Age  Gender Marital Status    Education Level  \
# 0            84966   23  Female        Married   Associate Degree
# 1            95568   26    Male        Widowed          Doctorate
# 2            10544   29  Female         Single   Associate Degree
# 3            77033   20    Male       Divorced  Bachelor's Degree
# 4            88160   25  Female      Separated  Bachelor's Degree
# ...            ...  ...     ...            ...                ...
# 53498        44809   35  Female       Divorced   Associate Degree
# 53499        65485   61    Male         Single          Doctorate
# 53500        26213   25    Male       Divorced          Doctorate
# 53501        63136   42    Male        Married          Doctorate
# 53502        62125   20    Male       Divorced          Doctorate
#
#             Geographic Information    Occupation  Income Level  \
# 0                          Mizoram  Entrepreneur         70541
# ...

# %%
# https://cabu.kcg.gov.tw/web/StatRptsFileList.aspx?catId=16504724-317b-4d57-8396-bd0af78b5ed4
#高雄統計

# %% [markdown]
# # Disney+ Movies and TV Shows
#
# ### [未清理版本](https://www.kaggle.com/datasets/shivamb/disney-movies-and-tv-shows/data)
#
# ### 欄位
# - **show_id**
# - **type**
# - **title**
# - **director**
# - **cast**
# - **country**
# - **date_added**
# - **release_year**
# - **rating**
# - **duration**
# - **listed_in**
# - **description**
#
# ### 備註
# - 1450 × 12

# %%
# https://www.kaggle.com/datasets/shivamb/disney-movies-and-tv-shows/data
df = pd.read_csv("disney_plus.csv")
df
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %% [markdown]
# # 台灣各縣市提供之開放資料
#
# ### [已清理資料-縣市](https://github.com/slowpoke1025/dv/blob/main/counties.csv)
# ### [全國資料](https://winstacity.dgbas.gov.tw/DgbasWeb/ZWeb/StateFile_ZWeb.aspx?Type=table&Area=)
# ### [高雄各區資料](https://cabu.kcg.gov.tw/web/StatRptsFileList.aspx?catId=16504724-317b-4d57-8396-bd0af78b5ed4)
#
#
# ### [視覺化範例1](https://gis.ris.gov.tw/dashboard.html)
# ### [視覺化範例2](https://plotdb.com/chart/12706/v1/)
#
#
#
# ### 欄位
# - **地區**
# - **土地面積(平方公里)**
# - **戶籍登記戶數(戶)**
# - **戶籍登記人口數(人)**
# - **0-14歲人口數(人)**
# - **15-64歲人口數(人)**
# - **65歲以上人口數(人)**
# - **幼年人口比率(0-14歲)(％)**
# - **青壯年人口比率(15-64歲)(％)**
# - **老年人口比率(65歲以上)(％)**
# - **扶養比()**
# - **老化指數()**
# - **男性人口(人)**
# - **女性人口(人)**
# - **性比例(女=100)**
# - **出生登記數(人)**
# - **死亡登記數(人)**
# - **粗出生率(‰)**
# - **粗死亡率(‰)**
# - **自然增加率(‰)**
# - **遷入人口數(人)**
# - **遷出人口數(人)**
# - **社會增加率(‰)**
# - **人口總增加率(‰)**
# - **人口密度(人/平方公里)**
# - **一般生育率(‰)**
# - **結婚登記對數(對)**
# - **離婚登記對數(對)**
# - **相同性別結婚登記對數(對)**
# - **粗結婚率(‰)**
# - **粗離婚率(‰)**
# - **勞動力人口數(千人)**
# - **失業率(％)**
# - **就業人口數(千人)**
# - **就業者之行業結構-工業(％)**
# - **就業者之行業結構-服務業(％)**
# - **就業者之行業結構-農林漁牧業(％)**
# - **就業者之教育程度結構-大專及以上(％)**
# - **就業者之教育程度結構-高中(職)(％)**
# - **就業者之教育程度結構-國中及以下(％)**
# - **總工時(小時)**
# - **公教人員人數(人)**
# - **刑案發生數(件)**
# - **刑案破獲數(件)**
# - **嫌疑犯人數(人)**
# - **刑案發生率(件/十萬人)**
# - **刑案破獲率(％)**
# - **犯罪人口率(人/十萬人)**
# - **少年犯罪人口率(人/十萬人)**
# - **青年犯罪人口率(人/十萬人)**
# - **成年犯罪人口率(人/十萬人)**
# - **道路交通事故肇事總件數(件)**
# - **鄉鎮市區數(個)**
# - **低收入戶人口數(人)**
# - **森林面積(公頃)**
# - **森林地占土地面積比率(％)**
# - **電力用戶數(戶)**
# - **電力售電量(百萬度)**
# - **電力用戶平均每戶售電量(萬度/戶)**
#
# ### 備註
# - 可結合台灣縣市、鄉鎮區地圖，做地理空間視覺化
# - 篩選特定區域進行視覺化 (ex:整個高雄市、鹽埕區)
# - 可再結合其他來源縣市、鄉鎮資料
# - ex: 各地氣象狀況、人口、性別比、出生死亡率、移出移入、老人比例等等

# %%
df = pd.read_csv("county.csv")
df = df.drop(df.columns[0], axis=1).drop([0,1], axis=0)
df = df.iloc[0:23]
df = df.rename({df.columns[0]:"地區"}, axis = 1).set_index("地區")
df = df.replace(',', '', regex=True)
df = df.drop(["農戶數(戶)","觀光旅館平均房價(元)", "歲入(百萬元)", "耕地率(％)"], axis=1)
df = df.astype("float64")
df
# Out:
#       土地面積(平方公里)  戶籍登記戶數(戶)  戶籍登記人口數(人)  0-14歲人口數(人)  15-64歲人口數(人)  \
# 地區
# 臺灣地區    36013.73  9042821.0  23109362.0    2805896.0    16242847.0
# 新北市      2052.57  1638908.0   3995551.0     460811.0     2853380.0
# 臺北市       271.80  1050981.0   2480681.0     312209.0     1649878.0
# 桃園市      1220.95   878466.0   2281464.0     319714.0     1636005.0
# 臺中市      2214.90  1033821.0   2814459.0     379633.0     2010536.0
# 臺南市      2191.65   716543.0   1852997.0     213467.0     1305385.0
# 高雄市      2951.85  1136785.0   2728137.0     309049.0     1919113.0
# 宜蘭縣      2143.63   176074.0    449062.0      51141.0      314394.0
# 新竹縣      1427.54   215177.0    580503.0      91302.0      410033.0
# 苗栗縣      1820.31   197025.0    535132.0      62217.0      375010.0
# 彰化縣      1074.40   402420.0   1245239.0     151252.0      870239.0
# 南投縣      4106.44   179907.0    479595.0      49333.0      333698.0
# 雲林縣      1290.83   245397.0    664092.0      70283.0      460188.0
# ...
